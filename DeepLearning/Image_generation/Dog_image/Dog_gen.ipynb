# %%
from keras.preprocessing.image import load_img, img_to_array,ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
img = load_img('/content/dog.jpg',target_size=(256,256,3))

# %%
image_conv = img_to_array(img)

# %%
image_conv.shape
# Out:
# (256, 256, 3)

# %%
image_conv[0]
# Out:
# array([[151., 172., 107.],
#        [152., 173., 108.],
#        [152., 173., 108.],
#        [152., 173., 108.],
#        [152., 174., 109.],
#        [152., 174., 109.],
#        [154., 176., 111.],
#        [153., 175., 110.],
#        [153., 175., 110.],
#        [155., 177., 112.],
#        [155., 177., 112.],
#        [156., 178., 113.],
#        [156., 178., 113.],
#        [157., 179., 114.],
#        [156., 178., 113.],
#        [157., 179., 114.],
#        [158., 180., 115.],
#        [159., 181., 116.],
#        [161., 183., 118.],
#        [161., 183., 118.],
#        [162., 183., 118.],
#        [164., 185., 120.],
#        [164., 185., 120.],
#        [164., 184., 121.],
#        [165., 185., 122.],
#        [165., 185., 122.],
#        [165., 185., 122.],
#        [166., 186., 123.],
#        [167., 187., 124.],
#        [166., 186., 123.],
#        [166., 186., 123.],
#        [166., 186., 123.],
#        [166., 186., 123.],
#        [167., 187., 124.],
#        [166., 186., 123.],
#        [166., 187., 122.],
#        [166., 187., 122.],
#        [165., 187., 122.],
#        [166., 188., 123.],
#        [165., 187., 122.],
#        [166., 188., 123.],
#        [166., 188., 123.],
#        [166., 188., 123.],
#        [166., 188., 123.],
#        [166., 188., 123.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [166., 188., 123.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [167., 189., 124.],
#        [166., 191., 126.],
#        [165., 190., 125.],
#        [167., 192., 127.],
#        [167., 192., 127.],
#        [166., 191., 126.],
#        [168., 193., 128.],
#        [168., 193., 128.],
#        [168., 193., 128.],
#        [168., 193., 128.],
#        [167., 194., 127.],
#        [166., 193., 126.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [166., 193., 126.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [167., 194., 127.],
#        [168., 193., 128.],
#        [168., 193., 128.],
#        [168., 194., 129.],
#        [168., 194., 129.],
#        [168., 194., 129.],
#        [168., 194., 129.],
#        [170., 195., 130.],
#        [170., 195., 130.],
#        [169., 195., 130.],
#        [169., 195., 130.],
#        [170., 196., 131.],
#        [170., 196., 131.],
#        [169., 195., 130.],
#        [170., 196., 131.],
#        [170., 196., 131.],
#        [170., 196., 131.],
#        [171., 196., 131.],
#        [172., 197., 132.],
#        [172., 197., 131.],
#        [172., 197., 131.],
#        [173., 198., 132.],
#        [172., 197., 131.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [176., 198., 133.],
#        [175., 197., 132.],
#        [176., 198., 133.],
#        [175., 197., 132.],
#        [177., 199., 134.],
#        [176., 198., 133.],
#        [177., 199., 134.],
#        [176., 198., 133.],
#        [177., 199., 134.],
#        [177., 199., 134.],
#        [177., 199., 134.],
#        [178., 200., 136.],
#        [177., 199., 135.],
#        [177., 199., 135.],
#        [178., 200., 136.],
#        [177., 199., 135.],
#        [177., 199., 135.],
#        [178., 200., 136.],
#        [177., 199., 135.],
#        [178., 200., 136.],
#        [178., 200., 136.],
#        [177., 202., 137.],
#        [177., 202., 137.],
#        [177., 202., 137.],
#        [177., 202., 137.],
#        [179., 201., 137.],
#        [179., 201., 137.],
#        [180., 202., 138.],
#        [180., 202., 138.],
#        [180., 200., 139.],
#        [181., 201., 140.],
#        [182., 202., 141.],
#        [182., 202., 141.],
#        [183., 203., 142.],
#        [182., 202., 141.],
#        [182., 202., 141.],
#        [181., 201., 140.],
#        [181., 201., 140.],
#        [181., 201., 140.],
#        [182., 200., 140.],
#        [182., 200., 140.],
#        [182., 200., 140.],
#        [182., 200., 140.],
#        [182., 200., 140.],
#        [182., 200., 140.],
#        [181., 199., 139.],
#        [180., 198., 138.],
#        [180., 198., 138.],
#        [180., 198., 138.],
#        [180., 198., 138.],
#        [180., 198., 140.],
#        [179., 197., 139.],
#        [179., 199., 140.],
#        [177., 197., 138.],
#        [179., 199., 138.],
#        [178., 198., 137.],
#        [178., 200., 138.],
#        [177., 199., 137.],
#        [177., 199., 137.],
#        [177., 199., 137.],
#        [177., 199., 137.],
#        [177., 199., 137.],
#        [179., 201., 139.],
#        [177., 199., 137.],
#        [180., 200., 139.],
#        [180., 200., 139.],
#        [179., 199., 138.],
#        [179., 199., 138.],
#        [178., 198., 137.],
#        [178., 198., 137.],
#        [178., 198., 139.],
#        [177., 197., 138.],
#        [177., 197., 138.],
#        [177., 197., 138.],
#        [177., 197., 136.],
#        [177., 197., 136.],
#        [176., 198., 136.],
#        [175., 197., 135.],
#        [174., 196., 134.],
#        [174., 196., 134.],
#        [174., 196., 134.],
#        [174., 196., 134.],
#        [174., 194., 131.],
#        [174., 194., 131.],
#        [174., 194., 131.],
#        [174., 194., 131.],
#        [173., 193., 130.],
#        [173., 193., 130.],
#        [173., 193., 130.],
#        [171., 193., 129.],
#        [172., 194., 130.],
#        [172., 194., 132.],
#        [172., 194., 132.],
#        [172., 194., 132.],
#        [170., 192., 130.],
#        [169., 193., 131.],
#        [168., 192., 130.],
#        [168., 192., 130.],
#        [168., 192., 130.],
#        [169., 193., 131.],
#        [168., 192., 130.],
#        [170., 192., 130.],
#        [170., 192., 130.],
#        [170., 192., 130.],
#        [169., 191., 129.],
#        [168., 190., 128.],
#        [168., 190., 128.],
#        [168., 190., 128.],
#        [167., 189., 127.],
#        [167., 189., 125.],
#        [167., 189., 125.],
#        [166., 188., 124.],
#        [166., 188., 124.],
#        [166., 188., 124.],
#        [166., 188., 124.],
#        [166., 189., 121.],
#        [167., 190., 122.],
#        [167., 188., 123.],
#        [167., 188., 123.],
#        [166., 188., 123.],
#        [166., 188., 123.],
#        [165., 188., 120.],
#        [164., 187., 119.],
#        [165., 187., 122.],
#        [164., 187., 117.],
#        [165., 186., 117.],
#        [165., 186., 117.],
#        [163., 184., 115.],
#        [164., 185., 116.],
#        [163., 184., 115.],
#        [163., 184., 117.],
#        [163., 184., 117.],
#        [162., 183., 116.],
#        [161., 182., 115.],
#        [163., 182., 116.],
#        [162., 181., 115.],
#        [162., 181., 117.],
#        [162., 181., 117.],
#        [161., 180., 116.],
#        [160., 179., 115.],
#        [162., 178., 115.],
#        [162., 178., 115.],
#        [162., 178., 115.],
#        [162., 178., 115.],
#        [162., 178., 115.],
#        [161., 177., 114.],
#        [160., 176., 114.],
#        [160., 176., 114.],
#        [157., 175., 113.],
#        [157., 175., 113.],
#        [157., 175., 113.],
#        [157., 175., 113.]], dtype=float32)

# %%
x = image_conv.reshape((1,)+image_conv.shape)
x.shape
# Out:
# (1, 256, 256, 3)

# %%
dataGenerator = ImageDataGenerator(featurewise_center=True, width_shift_range=0.7, zoom_range=0.8,horizontal_flip=True, vertical_flip=True,rotation_range=45)

# %%
i = 1
for batch in dataGenerator.flow(x,batch_size=1,save_to_dir='/content/Dog_regen',save_format='png',save_prefix='horse'):
  i = i+1
  if(i>20):
    break
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
